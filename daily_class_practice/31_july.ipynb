# %% [markdown]
# ### 3. insert ()

# %%
list1=[10,20,30,40,50]
list1.insert(1, 25)
print(list1)
# Out:
# [10, 25, 20, 30, 40, 50]

# %% [markdown]
# ### 4.Extend ()

# %%
a=[10,20,30,40,50]
b=[60,70,80]
a.extend(b)
print(a)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %% [markdown]
# ## 2.Remove ()

# %%
list2=[10,20,30,40,50]
list2.remove(30)
print(list2)
list3=["hello", "world"]
list3.remove("hello")
print(list3)
# Out:
# [10, 20, 40, 50]
# ['world']

# %% [markdown]
# ### 2.pop ()

# %%
c=[10,20,30,40,50]
c.pop(2)
print(c)
# Out:
# [10, 20, 40, 50]
