# %% [markdown]
# ### 7.Searching

# %%
list1=[1,2,3,4,5,6,7]
#print(3 in list1)
if (55 in list1):
    print("yes")
else:
    print("no")
# Out:
# no

# %% [markdown]
# ### 8.identity

# %%
list1=[1,2,3,4,5,6,7]
list2=list1
print(list2 is list1)
# Out:
# True
