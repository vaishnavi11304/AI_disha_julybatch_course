# %% [markdown]
# ### SETS {}

# %%
a={"hello"}
print(type(a))
print(a)
# Out:
# <class 'set'>
# {'hello'}

# %% [markdown]
# ### SETS ARE UNORDERED

# %%
a1={10,20,30,40,50}
print(a1)
# Out:
# {50, 20, 40, 10, 30}

# %% [markdown]
# ### 1.HOMOGENEOUS ELEMENT

# %%
a={10,20,30,40,50}
print(type(a))
print(a)
# Out:
# <class 'set'>
# {50, 20, 40, 10, 30}

# %% [markdown]
# ### 2.HETROGENEOUSE ELEMRNT

# %%
c={"a",10,10.2,10+3j,True}
print(c)
# Out:
# {True, 10, (10+3j), 'a', 10.2}

# %% [markdown]
# ### EMPTY SET CREATION {}

# %%
set1=set()
print(type(set1))
# Out:
# <class 'set'>

# %% [markdown]
# ### ACCESING SET ELEMENT {}

# %% [markdown]
# ##### set is an unordered collection hence we cannot use indexing and slicing and also while loop

# %% [markdown]
# ### LOOPING IN SET

# %% [markdown]
# #### FOR LOOP {}

# %%
set1={10,20,30,40,50}
for i in set1:
    print(i)
# Out:
# 50
# 20
# 40
# 10
# 30

# %% [markdown]
# #### ENNUMERATE

# %%
set2={10,20,30,40,50}
for index,value in enumerate(set2):
    print(index,value)
# Out:
# 0 50
# 1 20
# 2 40
# 3 10
# 4 30

# %% [markdown]
# ### BASIC SET OPERATION

# %% [markdown]
# #### 1. MUTABILITY

# %%
a2={10,20,30,40,50}
set1.add(100)
print(set1)
# Out:
# {50, 20, 100, 40, 10, 30}

# %% [markdown]
# #### 2.CONVERSION {}

# %% [markdown]
# ##### 1. comverting string to set

# %%
str1="hello"
set1=set(str1)
print(str1)
# Out:
# hello

# %% [markdown]
# #### 2.Converting list to set {}

# %%
list1={10,20,30,40,50}
set1=set(list1)
print(set1)
# Out:
# {50, 20, 40, 10, 30}

# %% [markdown]
# #### 3. Converting tuple to set

# %%
tuple1={10,20,30,40,50}
set1=set(tuple1)
print(set1)
# Out:
# {50, 20, 40, 10, 30}

# %% [markdown]
# #### 4. CONVERTING DICT TO SET

# %%
dict1={"a",10,"b",20,"c",30}
set1=set(dict1)
print(set1)
# Out:
# {20, 'b', 'c', 10, 30, 'a'}

# %% [markdown]
# #### 5. Converting range () to set

# %%
set1=

# %% [markdown]
# ### 3.Aliasing ()

# %%
set1={10,20,30,40,50}
set2=set1
print(id(set1))
print(id(set2))
# Out:
# 2365756303936
# 2365756303936

# %% [markdown]
# ### 4. Clonning ()

# %%
set1={"hello", "world", "python"}
set2=set1.copy()
print(set1)
# Out:
# {'hello', 'world', 'python'}

# %% [markdown]
# ### 5. Searching ()

# %%
set1={10,20,30,40,50}
print(10 in set1)
# Out:
# True

# %% [markdown]
# ### 6. Identity - is operator ()

# %%
set1={10,20,30,40,50}
set2=set1
print(set1 is set2)
# Out:
# True

# %% [markdown]
# ### 7. Emptiness

# %%
set1=set()
print(not set1)

set={10,20,30,40,50}
print(not set2)
# Out:
# True
# False

# %% [markdown]
# #### we cannot impelment - comparison , conactenation , indexing , Slicing , while loop and duplicates are not allowed in tuples
#
# #### Unordered Collection

# %%
set1={10,20,30,40,50}
set2={30,40,50,60,70}
print(set1<set2)
# Out:
# False
