# %% [markdown]
# ### 3.Capitalize ()

# %%
a="jai shree krishna"
print(a)
b=a.capitalize()
print(b)
# Out:
# jai shree krishna
# Jai shree krishna

# %% [markdown]
# ### 4.Title ()

# %%
a="jai shree krishna"
print(a)
b=a.title()
print(b)
# Out:
# jai shree krishna
# Jai Shree Krishna

# %% [markdown]
# ### 5.Swapcase ()

# %%
a="JAI SHREE KRISHNA"
print(a)
b=a.swapcase()
print(b)
# Out:
# JAI SHREE KRISHNA
# jai shree krishna
